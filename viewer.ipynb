# %%
import controller as control

# %%
gan = control.Classic_GAN()

# %%
gan.learning_rate = 0.0005

# %%
gan.beta_1 = 0.005

# %%
gan.epochs = 600000
gan.batch_size = 5
gan.plot_batch_size = 10

# %%
gan.start_training()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 20)                220
#
#  dense_1 (Dense)             (None, 20)                420
#
#  dense_2 (Dense)             (None, 20)                420
#
#  dense_3 (Dense)             (None, 12288)             258048
#
# ...
# Total params: 259,108
# Trainable params: 259,108
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_4 (Dense)             (None, 20)                245780
#
#  dense_5 (Dense)             (None, 20)                420
#
#  dense_6 (Dense)             (None, 1)                 21
#
# ...
# Total params: 246,221
# Trainable params: 246,221
# Non-trainable params: 0
# ...

# %%
del gan
